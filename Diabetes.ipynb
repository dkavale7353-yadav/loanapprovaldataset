# %% [markdown]
# <a href="https://colab.research.google.com/github/dkavale7353-yadav/loanapprovaldataset/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb5d7f0d-e410-441a-8a7d-1329c94f52f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb5d7f0d-e410-441a-8a7d-1329c94f52f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('diabetes.csv')

# %%
df.columns= df.columns.str.strip().str.lower()

# %%
df.head()
# Out:
#     unnamed: 0 diabetes     unnamed: 2     unnamed: 3 unnamed: 4 unnamed: 5  \
# 0          NaN      NaN            NaN            NaN        NaN        NaN
# 1          NaN      NaN            NaN            NaN        NaN        NaN
# 2  Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin        BMI
# 3            6      148             72             35          0       33.6
# 4            1       85             66             29          0       26.6
#
#                  unnamed: 6 unnamed: 7 unnamed: 8
# 0                       NaN        NaN        NaN
# 1                       NaN        NaN        NaN
# 2  DiabetesPedigreeFunction        Age    Outcome
# 3                     0.627         50          1
# 4                     0.351         31          0

# %%
df.shape
# Out:
# (771, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Diabetes', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 771 entries, 0 to 770
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  769 non-null    object
#  1   Diabetes    769 non-null    object
#  2   Unnamed: 2  769 non-null    object
#  3   Unnamed: 3  769 non-null    object
#  4   Unnamed: 4  769 non-null    object
#  5   Unnamed: 5  769 non-null    object
#  6   Unnamed: 6  769 non-null    object
#  7   Unnamed: 7  769 non-null    object
#  8   Unnamed: 8  769 non-null    object
# dtypes: object(9)
# memory usage: 54.3+ KB

# %%
df.shape
# Out:
# (771, 9)

# %%
(df == 0).any()
# Out:
# Unnamed: 0    False
# Diabetes      False
# Unnamed: 2    False
# Unnamed: 3    False
# Unnamed: 4    False
# Unnamed: 5    False
# Unnamed: 6    False
# Unnamed: 7    False
# Unnamed: 8    False
# dtype: bool

# %%
df.columns=df.columns.str.strip().str.lower()

# %%
df.isnull().sum()

# %%
#import missing values
for col in invalid_zero_cols:
  df[col].fillna(df[col].median(), inplace=True)

# %%
# mediam represent:a typical patient not too high not too low not infuenced bu outliers

# %%
#feature target separation
#feature
x=df.drop(columns=['outcome'])
#target
y=df['outcome']

# %%
y.name

# %%
x.columns

# %%
#train and test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)

# %%
x_train.shape,x_test.shape

# %%
y.value_counts()

# %%
y_train.value_counts()

# %%
y_test.value_counts()

# %%
#feature scaling-preprocessing
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# here using logistic regression classifier beacause it is a binary classification problem,strong base kube for medical data
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_reg.fit(x_train_scaled,y_train)
# here now the model trraind uses scaled features can impleent safely

# %%
y_pred=log_reg.predict(x_test_scaled)

# %%
#predictions
y_pred[:10]

# %%
log_reg.score(x_test_scaled,y_test)
#accuracy test

# %%
log_reg.score(x_train_scaled,y_train)
#accuracy train

# %%
#linear regression probablity prediction
y_prob=log_reg.predict_proba(x_test_scaled)

# %%
y_prob[:20]

# %%
y_prob_diabetic=y_prob[:,1]
y_prob_diabetic[:10]

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm

# [TM FP]
# [FN TP]
# TN-true negative-actually not diabetic
# FP-false positive-actually not diabetic but predicted diabetic
# FN-false negative-actually diabetic but predicted diabetic
# TP-true positive-actually diabetic

# %%
#classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(x_train_scaled,y_train)

# %%
y_pred_svm=svm_model.predict(x_test_scaled)
# evaluating
svm_model.score(x_test_scaled,y_test)

# %%
svm_model.score(x_test_scaled,y_test)

# %%
y_prob_svm[:10]

# %%
y_prob_svm=svm_model.predict_proba(x_test_scaled)
y_prob_svm[:10]
